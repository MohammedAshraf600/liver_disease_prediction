# %% [markdown]
# # Name: Mohammed Ashraf
#
# # Company: CodeAlpha
#
# # Project:liver_disease_Prediction_project

# %%
#for data precessing 
import pandas as pd
import numpy as np
#for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set()
plt.style.use('ggplot')

# %%
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('indian_liver_patient.csv')

# %% [markdown]
# # Task:
#
# DATA PREPROCESSING:
#
# Handle missing values and outliers appropriately.
# Normalize or scale features as needed.
# Split the data into training and testing sets.
#
#
# # Description:
#
# 'Age':
# Represents the age of the individual.
#
# 'Gender':
# Represents the gender of the individual.
#
# 'Total_Bilirubin':
# Total amount of bilirubin in the blood.
#
# 'Direct_Bilirubin':
# Amount of direct bilirubin in the blood.
#
# 'Alkaline_Phosphotase':
# Alkaline phosphatase enzyme levels in the blood.
#
# 'Alamine_Aminotransferase':
# ALT (Alanine Aminotransferase) enzyme levels in the blood.
#
# 'Aspartate_Aminotransferase':
# AST (Aspartate Aminotransferase) enzyme levels in the blood.
#
# 'Total_Protiens':
# Total protein levels in the blood.
#
# 'Albumin':
# Albumin levels in the blood.
#
# 'Albumin_and_Globulin_Ratio':
# Ratio of albumin to globulin in the blood.
#
# 'Dataset':
# Represents the presence or absence of a liver disease (target variable).

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df.shape
# Out:
# (583, 11)

# %%
df.size
# Out:
# 6413

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
#extract the categorical columns
df.dtypes[df.dtypes=='object']
# Out:
# Gender    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
#Destribution of numerical features
df.hist(figsize=(15,15),xrot=45 ,bins=10)
plt.show()

# %%
#function to category column dataset from (2 and 1) to (1 and 0)
def convertdataset(x):
    if x==2:
        return 0
    else:
        return 1
df["Dataset"]=df["Dataset"].map(convertdataset)

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.Dataset.value_counts()
# Out:
# 1    416
# 0    167
# Name: Dataset, dtype: int64

# %%
# Count the number of people with 'Dataset' values 1 and 0 for each 'Gender'
for gender, group_df in df.groupby('Gender'):
    print(f"\nGender: {gender}")
    
    # Count for 'Dataset' value 1
    count_dataset_1 = group_df[group_df['Dataset'] == 1].shape[0]
    print(f"Count of 'Dataset' 1: {count_dataset_1}")
    
    # Count for 'Dataset' value 0
    count_dataset_0 = group_df[group_df['Dataset'] == 0].shape[0]
    print(f"Count of 'Dataset' 0: {count_dataset_0}")
# Out:
# Gender: Female
# Count of 'Dataset' 1: 92
# Count of 'Dataset' 0: 50
#
# Gender: Male
# Count of 'Dataset' 1: 324
# Count of 'Dataset' 0: 117

# %%
#Distribution of Gender column (categorical_feature)
plt.figure(figsize=(12,8))
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Distribution of 'Gender' column grouped by 'Dataset'
plt.figure(figsize=(12, 8))
sns.countplot(x='Dataset', hue='Gender', data=df)
plt.title('Distribution of Gender grouped by Dataset')
plt.show()

# %%
df[df['Gender']=='Male'][['Dataset','Gender']]
# Out:
#      Dataset Gender
# 1          1   Male
# 2          1   Male
# 3          1   Male
# 4          1   Male
# 5          1   Male
# ..       ...    ...
# 578        0   Male
# 579        1   Male
# 580        1   Male
# 581        1   Male
# 582        0   Male
#
# [441 rows x 2 columns]

# %%
#Distribution of Gender grouped by Dataset
sns.catplot(x="Age", y="Gender", hue="Dataset", data=df)
plt.show()

# %%
#Distribution of gender
df['Gender'].value_counts()
# Out:
# Male      441
# Female    142
# Name: Gender, dtype: int64

# %%
#Categorical value handling
def convert_gender(x):
    if x=='Male':
        return 0
    else:
        return 1
df['Gender']=df['Gender'].map(convert_gender)

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       1              0.7               0.1                   187
# 1   62       0             10.9               5.5                   699
# 2   62       0              7.3               4.1                   490
# 3   58       0              1.0               0.4                   182
# 4   72       0              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %% [markdown]
# # Correlation

# %% [markdown]
# # Notes:
# ### Positive correlation -> one feature increase other also increase
# ### Nigative correlation -> one feature increase other also decrease
# ### closer to 0 -> weak relationship

# %%
df.corr()
# Out:
#                                  Age    Gender  Total_Bilirubin  \
# Age                         1.000000 -0.056560         0.011763
# Gender                     -0.056560  1.000000        -0.089291
# Total_Bilirubin             0.011763 -0.089291         1.000000
# Direct_Bilirubin            0.007529 -0.100436         0.874618
# Alkaline_Phosphotase        0.080425  0.027496         0.206669
# Alamine_Aminotransferase   -0.086883 -0.082332         0.214065
# Aspartate_Aminotransferase -0.019910 -0.080336         0.237831
# Total_Protiens             -0.187461  0.089121        -0.008099
# Albumin                    -0.265924  0.093799        -0.222250
# Albumin_and_Globulin_Ratio -0.216408  0.003424        -0.206267
# Dataset                     0.137351 -0.082416         0.220208
#
#                             Direct_Bilirubin  Alkaline_Phosphotase  \
# Age                                 0.007529              0.080425
# ...

# %%
#correlation plot -> heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# Create a mask to hide the upper triangle of the correlation matrix
mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)]= True
plt.figure(figsize=(12,8))

# Use a white background
with sns.axes_style("white"):
    # Create the heatmap
    ax = sns.heatmap(df.corr() * 100, mask=mask, fmt=".0f", annot=True, lw=1, cmap=ListedColormap(['red','yellow', 'green', 'blue']))

# %%
#correlation 
correlation_matrix = df.corr()

#setting the plot
plt.figure(figsize=(12, 8))

# Create a heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)

# Show the plot
plt.show()

# %% [markdown]
# # Data_preprocessting

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
#fill nulls with mean
df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age      Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  570.000000  570.000000       570.000000        570.000000
# mean    44.849123    0.245614         3.321754          1.497544
# std     16.242182    0.430829         6.267941          2.833231
# min      4.000000    0.000000         0.400000          0.100000
# 25%     33.000000    0.000000         0.800000          0.200000
# 50%     45.000000    0.000000         1.000000          0.300000
# 75%     58.000000    0.000000         2.600000          1.300000
# max     90.000000    1.000000        75.000000         19.700000
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count            570.000000                570.000000
# mean             291.750877                 79.728070
# std              245.291859                181.471697
# min               63.000000                 10.000000
# 25%              176.000000                 23.000000
# ...

# %%
#see outliers in Alkaline_Phosphotase column
sns.boxplot(df.Alkaline_Phosphotase)
# Out:
# <Axes: >

# %%
#see outliers in Alamine_Aminotransferase column
sns.boxplot(df.Alamine_Aminotransferase)
# Out:
# <Axes: >

# %%
#see outliers in Aspartate_Aminotransferase column
sns.boxplot(df.Aspartate_Aminotransferase)
# Out:
# <Axes: >

# %%
#see outliers in Total_Bilirubin column
sns.boxplot(df.Total_Bilirubin)
# Out:
# <Axes: >

# %%
#displaying the top 5 values of Alkaline_Phosphotase column
df.Alkaline_Phosphotase.sort_values(ascending=False).head()
# Out:
# 233    2110
# 128    1896
# 429    1750
# 116    1630
# 77     1620
# Name: Alkaline_Phosphotase, dtype: int64

# %%
#displaying the top 5 values of Alamine_Aminotransferase column
df.Alamine_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 117    2000
# 27     1680
# 47     1630
# 118    1350
# 135    1250
# Name: Alamine_Aminotransferase, dtype: int64

# %%
#displaying the top 5 values of Total_Bilirubin column
df.Total_Bilirubin.sort_values(ascending=False).head()
# Out:
# 166    75.0
# 559    42.8
# 505    32.6
# 531    30.8
# 504    30.5
# Name: Total_Bilirubin, dtype: float64

# %%
#as we see there are outliers in Aspartate_Aminotransferase column
df.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 135    4929
# 117    2946
# 118    1600
# 207    1500
# 199    1050
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
df=df[df.Aspartate_Aminotransferase<=3000]

# %%
df.shape
# Out:
# (569, 11)

# %%
df.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 117    2946
# 118    1600
# 207    1500
# 119    1050
# 199    1050
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
df=df[df.Aspartate_Aminotransferase <=2500]

# %%
df.Aspartate_Aminotransferase.sort_values(ascending=False).head()
# Out:
# 118    1600
# 207    1500
# 199    1050
# 119    1050
# 47      960
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
df.shape
# Out:
# (568, 11)

# %% [markdown]
# # Data visualization

# %% [markdown]
# # Grouping age

# %%
# Here we mapping age for making the visualization more clear 
age_bins = [0, 18, 35, 50, 100]  
age_labels = ['0-18', '19-35', '36-50', '51+']

df['age_group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# %% [markdown]
# # Total_Bilirubin groupby age

# %%
data = df.groupby('age_group')['Total_Bilirubin'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Total_Bilirubin':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Total_Bilirubin','ro-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Total_Bilirubin');
plt.title('age vs Average_Total_Bilirubin');

# %% [markdown]
# # Direct_Bilirubin groupby age

# %%
data = df.groupby('age_group')['Direct_Bilirubin'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Direct_Bilirubin':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Direct_Bilirubin','bo-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Direct_Bilirubin');
plt.title('age vs Average_Direct_Bilirubin');

# %% [markdown]
# # Alkaline_Phosphotase groupby age

# %%
data = df.groupby('age_group')['Alkaline_Phosphotase'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Alkaline_Phosphotase':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Alkaline_Phosphotase','ro-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Alkaline_Phosphotase');
plt.title('age vs Average_DAlkaline_Phosphotase');

# %% [markdown]
# # Alamine_Aminotransferase groupby age

# %%
data = df.groupby('age_group')['Alamine_Aminotransferase'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Alamine_Aminotransferase':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Alamine_Aminotransferase','ro-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Alamine_Aminotransferase');
plt.title('age vs Average_Alamine_Aminotransferase');

# %% [markdown]
# # Aspartate_Aminotransferase groupby age

# %%
data = df.groupby('age_group')['Aspartate_Aminotransferase'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Aspartate_Aminotransferase':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Aspartate_Aminotransferase','bo-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Aspartate_Aminotransferase');
plt.title('age vs Average_Aspartate_Aminotransferase');

# %% [markdown]
# # Total_Protiens groupby age

# %%
data = df.groupby('age_group')['Total_Protiens'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Total_Protiens':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Total_Protiens','ro-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Total_Protiens');
plt.title('age vs Average_Total_Protiens');

# %% [markdown]
# # Albumin groupby age

# %%
data = df.groupby('age_group')['Albumin'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Albumin':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Albumin','bo-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Albumin');
plt.title('age vs Average_Albumin');

# %% [markdown]
# # Albumin_and_Globulin_Ratio groupby age

# %%
data = df.groupby('age_group')['Albumin_and_Globulin_Ratio'].mean()
data  = pd.DataFrame({'age':data.index, 'Average_Albumin_and_Globulin_Ratio':data.values})
plt.figure(figsize = (10,5))
plt.plot('age','Average_Albumin_and_Globulin_Ratio','ro-',data = data);
plt.grid();
plt.xlabel('age');
plt.ylabel('Average_Albumin_and_Globulin_Ratio');
plt.title('age vs Average_Albumin_and_Globulin_Ratio');

# %% [markdown]
# # Data Analysis

# %%
# Calculate the max and min of 'Total_Bilirubin' for each 'age_group'
max_values = df.groupby('age_group')['Total_Bilirubin'].max()
min_values = df.groupby('age_group')['Total_Bilirubin'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     27.2
# 19-35    42.8
# 36-50    30.8
# 51+      75.0
# Name: Total_Bilirubin, dtype: float64
#
# Min Values:
# age_group
# 0-18     0.5
# 19-35    0.6
# 36-50    0.5
# 51+      0.4
# Name: Total_Bilirubin, dtype: float64

# %%
# Calculate the max and min of 'Direct_Bilirubin' for each 'age_group'
max_values = df.groupby('age_group')['Direct_Bilirubin'].max()
min_values = df.groupby('age_group')['Direct_Bilirubin'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     11.8
# 19-35    19.7
# 36-50    18.3
# 51+      12.6
# Name: Direct_Bilirubin, dtype: float64
#
# Min Values:
# age_group
# 0-18     0.1
# 19-35    0.1
# 36-50    0.1
# 51+      0.1
# Name: Direct_Bilirubin, dtype: float64

# %%
# Calculate the max and min of 'Alkaline_Phosphotase' for each 'age_group'
max_values = df.groupby('age_group')['Alkaline_Phosphotase'].max()
min_values = df.groupby('age_group')['Alkaline_Phosphotase'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     1420
# 19-35    2110
# 36-50    1630
# 51+      1896
# Name: Alkaline_Phosphotase, dtype: int64
#
# Min Values:
# age_group
# 0-18     145
# 19-35     63
# 36-50     92
# 51+       92
# Name: Alkaline_Phosphotase, dtype: int64

# %%
# Calculate the max and min of 'Alamine_Aminotransferase' for each 'age_group'
max_values = df.groupby('age_group')['Alamine_Aminotransferase'].max()
min_values = df.groupby('age_group')['Alamine_Aminotransferase'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18      790
# 19-35    1680
# 36-50    1630
# 51+       412
# Name: Alamine_Aminotransferase, dtype: int64
#
# Min Values:
# age_group
# 0-18     17
# 19-35    10
# 36-50    10
# 51+      10
# Name: Alamine_Aminotransferase, dtype: int64

# %%
# Calculate the max and min of 'Aspartate_Aminotransferase' for each 'age_group'
max_values = df.groupby('age_group')['Aspartate_Aminotransferase'].max()
min_values = df.groupby('age_group')['Aspartate_Aminotransferase'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     1050
# 19-35    1600
# 36-50    1500
# 51+       850
# Name: Aspartate_Aminotransferase, dtype: int64
#
# Min Values:
# age_group
# 0-18     16
# 19-35    10
# 36-50    11
# 51+      12
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
# Calculate the max and min of 'Total_Protiens' for each 'age_group'
max_values = df.groupby('age_group')['Total_Protiens'].max()
min_values = df.groupby('age_group')['Total_Protiens'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     8.9
# 19-35    9.6
# 36-50    9.5
# 51+      8.6
# Name: Total_Protiens, dtype: float64
#
# Min Values:
# age_group
# 0-18     4.8
# 19-35    2.8
# 36-50    3.6
# 51+      2.7
# Name: Total_Protiens, dtype: float64

# %%
# Calculate the max and min of 'Albumin' for each 'age_group'
max_values = df.groupby('age_group')['Albumin'].max()
min_values = df.groupby('age_group')['Albumin'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     4.9
# 19-35    5.5
# 36-50    5.5
# 51+      4.9
# Name: Albumin, dtype: float64
#
# Min Values:
# age_group
# 0-18     2.0
# 19-35    0.9
# 36-50    1.0
# 51+      0.9
# Name: Albumin, dtype: float64

# %%
# Calculate the max and min of 'Albumin_and_Globulin_Ratio' for each 'age_group'
max_values = df.groupby('age_group')['Albumin_and_Globulin_Ratio'].max()
min_values = df.groupby('age_group')['Albumin_and_Globulin_Ratio'].min()

# Display the results
print("Max Values:")
print(max_values)

print("\nMin Values:")
print(min_values)
# Out:
# Max Values:
# age_group
# 0-18     1.7
# 19-35    2.5
# 36-50    2.8
# 51+      1.9
# Name: Albumin_and_Globulin_Ratio, dtype: float64
#
# Min Values:
# age_group
# 0-18     0.4
# 19-35    0.3
# 36-50    0.3
# 51+      0.3
# Name: Albumin_and_Globulin_Ratio, dtype: float64

# %%
# Count the number of people with 'Dataset' values 1 and 0 for each 'age_group'
for age_group, group_df in df.groupby('age_group'):
    print(f"\nAge Group: {age_group}")
    
    # Count for 'Dataset' value 1
    count_dataset_1 = group_df[group_df['Dataset'] == 1].shape[0]
    print(f"Count of 'Dataset' 1: {count_dataset_1}")
    
    # Count for 'Dataset' value 0
    count_dataset_0 = group_df[group_df['Dataset'] == 0].shape[0]
    print(f"Count of 'Dataset' 0: {count_dataset_0}")
# Out:
# Age Group: 0-18
# Count of 'Dataset' 1: 12
# Count of 'Dataset' 0: 13
#
# Age Group: 19-35
# Count of 'Dataset' 1: 93
# Count of 'Dataset' 0: 43
#
# Age Group: 36-50
# Count of 'Dataset' 1: 127
# Count of 'Dataset' 0: 53
#
# Age Group: 51+
# Count of 'Dataset' 1: 172
# Count of 'Dataset' 0: 55

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       1              0.7               0.1                   187
# 1     62       0             10.9               5.5                   699
# 2     62       0              7.3               4.1                   490
# 3     58       0              1.0               0.4                   182
# 4     72       0              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       0              0.5               0.1                   500
# 579   40       0              0.6               0.1                    98
# 580   52       0              0.8               0.2                   245
# 581   31       0              1.3               0.5                   184
# 582   38       0              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %% [markdown]
# # Machine Learning models

# %%
#splitting data
X = df.drop(['Dataset', 'age_group'], axis=1)
y=df.Dataset

# %%
X.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio'],
#       dtype='object')

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 578    0
# 579    1
# 580    1
# 581    1
# 582    0
# Name: Dataset, Length: 568, dtype: int64

# %%
# Importing necessary libraries for machine learning tasks
from sklearn.model_selection import train_test_split  # Splitting data into training and testing sets
from sklearn.model_selection import GridSearchCV  # Grid search for hyperparameter tuning
from sklearn.model_selection import cross_val_score  # Cross-validation for model evaluation
from sklearn.linear_model import LogisticRegression  # Logistic Regression classifier
from sklearn.ensemble import RandomForestClassifier  # Random Forest classifier
from xgboost import XGBClassifier  # XGBoost classifier
from sklearn.tree import DecisionTreeClassifier  # Decision Tree classifier
from sklearn.svm import SVC  # Support Vector Machine classifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report  # Metrics for model evaluation

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0 )

# %% [markdown]
# # Data Standarization
#
# The standardization of data is typically performed using the following formula for each feature:
#
# z = (X- mean_of_feature)/standard_deviation
#
# The purpose of standardization:
# Improving convergence: Standardizing data can help optimization algorithms converge faster during the training of machine learning models.

# %%
X
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       1              0.7               0.1                   187
# 1     62       0             10.9               5.5                   699
# 2     62       0              7.3               4.1                   490
# 3     58       0              1.0               0.4                   182
# 4     72       0              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       0              0.5               0.1                   500
# 579   40       0              0.6               0.1                    98
# 580   52       0              0.8               0.2                   245
# 581   31       0              1.3               0.5                   184
# 582   38       0              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
train_mean = x_train.mean()
train_std = x_train.std()

# %%
x_train =(x_train - train_mean) / train_std

# %%
x_train.describe()
# Out:
#                 Age        Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  4.540000e+02  4.540000e+02     4.540000e+02      4.540000e+02
# mean   5.086484e-17 -2.543242e-17    -1.173804e-16     -3.130144e-17
# std    1.000000e+00  1.000000e+00     1.000000e+00      1.000000e+00
# min   -2.533647e+00 -5.682450e-01    -4.589275e-01     -4.959149e-01
# 25%   -7.425175e-01 -5.682450e-01    -3.974981e-01     -4.604310e-01
# 50%    6.040267e-02 -5.682450e-01    -3.667834e-01     -4.249471e-01
# 75%    8.015598e-01 -5.682450e-01    -1.057086e-01     -7.010806e-02
# max    2.777979e+00  1.755928e+00     1.099765e+01      6.458930e+00
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count          4.540000e+02              4.540000e+02
# mean           1.369438e-17             -3.717046e-17
# std            1.000000e+00              1.000000e+00
# min           -9.594949e-01             -3.982123e-01
# 25%           -4.703267e-01             -3.203791e-01
# ...

# %%
x_test = (x_test - train_mean) / train_std

# %%
x_test.describe()
# Out:
#               Age      Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  114.000000  114.000000       114.000000        114.000000
# mean    -0.057706    0.022992        -0.074320         -0.027465
# std      1.017415    1.016682         0.787802          1.018002
# min     -2.533647   -0.568245        -0.443570         -0.495915
# 25%     -0.788840   -0.568245        -0.397498         -0.460431
# 50%     -0.094005   -0.568245        -0.382141         -0.424947
# 75%      0.786119    1.174885        -0.186335         -0.141076
# max      2.036822    1.755928         4.209705          5.962155
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count            114.000000                114.000000
# mean               0.040520                 -0.066345
# std                1.167355                  0.567701
# min               -0.768081                 -0.398212
# 25%               -0.497975                 -0.312895
# ...

# %% [markdown]
# # logistic Regression

# %%
# Initialize the Logistic Regression model
lr_model = LogisticRegression()

# Train the model on the training set
lr_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_lr = lr_model.predict(x_train)
# Make predictions on the testing set
y_test_pred_lr = lr_model.predict(x_test)

# Get feature importance (absolute values of coefficients)
feature_importance = abs(lr_model.coef_[0])

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for Logistic Regression')
plt.xlabel('Feature Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.show()

# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_lr))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_lr))

# Display confusion matrix and classification report for testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_lr))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_lr))
# Out:
# Training Accuracy: 0.7422907488986784
# Testing Accuracy: 0.6403508771929824
#
# Confusion Matrix:
# [[ 9 38]
#  [ 3 64]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.19      0.31        47
#            1       0.63      0.96      0.76        67
#
#     accuracy                           0.64       114
#    macro avg       0.69      0.57      0.53       114
# weighted avg       0.68      0.64      0.57       114

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN classifier
knn_model = KNeighborsClassifier(n_neighbors=3)

# Train the model on the training set
knn_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_knn = knn_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_knn = knn_model.predict(x_test)


#plotting Feature Distribution for KNN
plt.figure(figsize=(30, 20))
sns.boxplot(data=x_test, palette="viridis")
plt.title('Feature Distribution for KNN on testing dataset')
plt.xlabel('Features')
plt.ylabel('Values')
plt.show()

# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_knn))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_knn))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_knn))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_knn))
# Out:
# Training Accuracy: 0.8237885462555066
# Testing Accuracy: 0.6403508771929824
#
# Confusion Matrix:
# [[16 31]
#  [10 57]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.34      0.44        47
#            1       0.65      0.85      0.74        67
#
#     accuracy                           0.64       114
#    macro avg       0.63      0.60      0.59       114
# weighted avg       0.63      0.64      0.61       114

# %% [markdown]
# # SVC

# %%
# Initialize the Support Vector Classifier (SVC)
svc_model = SVC(kernel='linear', random_state=42)

# Train the model on the training set
svc_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_svc = svc_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_svc = svc_model.predict(x_test)

# Get feature importance (absolute values of coefficients)
feature_importance = abs(svc_model.coef_[0])

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for SVC')
plt.xlabel('Feature Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.show()

# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_svc))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_svc))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_svc))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_svc))
# Out:
# Training Accuracy: 0.7422907488986784
# Testing Accuracy: 0.5877192982456141
#
# Confusion Matrix:
# [[ 0 47]
#  [ 0 67]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        47
#            1       0.59      1.00      0.74        67
#
#     accuracy                           0.59       114
#    macro avg       0.29      0.50      0.37       114
# weighted avg       0.35      0.59      0.44       114

# %% [markdown]
# # Decision Tree classifier
#
# note:Decision Tree model here gives me overfitting

# %%
# Initialize the Decision Tree classifier
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model on the training set
dt_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_dt = dt_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_dt = dt_model.predict(x_test)

# Get feature importance
feature_importance = dt_model.feature_importances_

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for Decision Tree Classifier')
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.show()


# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_dt))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_dt))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_dt))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_dt))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.5701754385964912
#
# Confusion Matrix:
# [[15 32]
#  [17 50]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.32      0.38        47
#            1       0.61      0.75      0.67        67
#
#     accuracy                           0.57       114
#    macro avg       0.54      0.53      0.53       114
# weighted avg       0.55      0.57      0.55       114

# %% [markdown]
# # XGBoost classifier
#
# note:XGBoost classifier model here gives me overfitting also

# %%
# Initialize the XGBoost classifier
xgb_model = XGBClassifier(random_state=42)

# Train the model on the training set
xgb_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_xgb = xgb_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_xgb = xgb_model.predict(x_test)

# Get feature importance
feature_importance = xgb_model.feature_importances_

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for XGBoost classifier')
plt.xlabel('Feature Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.show()


# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_xgb))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_xgb))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_xgb))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_xgb))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.6228070175438597
#
# Confusion Matrix:
# [[15 32]
#  [11 56]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.32      0.41        47
#            1       0.64      0.84      0.72        67
#
#     accuracy                           0.62       114
#    macro avg       0.61      0.58      0.57       114
# weighted avg       0.61      0.62      0.59       114

# %% [markdown]
# # GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Initialize the Gradient Boosting classifier
gb_model = GradientBoostingClassifier(random_state=42)

# Train the model on the training set
gb_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_gb = gb_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_gb = gb_model.predict(x_test)

# Get feature importance
feature_importance = gb_model.feature_importances_

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for Gradient_Boosting')
plt.xlabel('Feature Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.show()

# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_gb))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_gb))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_gb))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_gb))
# Out:
# Training Accuracy: 0.9449339207048458
# Testing Accuracy: 0.5789473684210527
#
# Confusion Matrix:
# [[12 35]
#  [13 54]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.26      0.33        47
#            1       0.61      0.81      0.69        67
#
#     accuracy                           0.58       114
#    macro avg       0.54      0.53      0.51       114
# weighted avg       0.55      0.58      0.54       114

# %% [markdown]
# # Random Forest classifier
# note:Random Forest classifier model here gives me overfitting also

# %%
# Initialize the Random Forest classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training set
rf_model.fit(x_train, y_train)

# Make predictions on the training set
y_train_pred_rf = rf_model.predict(x_train)

# Make predictions on the testing set
y_test_pred_rf = rf_model.predict(x_test)

# Get feature importance
feature_importance = rf_model.feature_importances_

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance, y=x_train.columns, palette="viridis")
plt.title(f'Feature Importance for Random Forest classifier')
plt.xlabel('Feature Importance (Absolute Coefficients)')
plt.ylabel('Features')
plt.show()

# Evaluate the model
print("Training Accuracy:", accuracy_score(y_train, y_train_pred_rf))
print("Testing Accuracy:", accuracy_score(y_test, y_test_pred_rf))

# Display confusion matrix and classification report for the testing set
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_test_pred_rf))

print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_rf))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.5964912280701754
#
# Confusion Matrix:
# [[ 8 39]
#  [ 7 60]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.17      0.26        47
#            1       0.61      0.90      0.72        67
#
#     accuracy                           0.60       114
#    macro avg       0.57      0.53      0.49       114
# weighted avg       0.58      0.60      0.53       114

# %% [markdown]
# # model comparasion

# %%
#the score of the models
lr_acc = accuracy_score(y_test, y_test_pred_lr)
knn_acc = accuracy_score(y_test, y_test_pred_knn)
svc_acc = accuracy_score(y_test, y_test_pred_svc)
dtc_acc = accuracy_score(y_test, y_test_pred_dt)
rfc_acc = accuracy_score(y_test, y_test_pred_rf)
gbc_acc = accuracy_score(y_test, y_test_pred_gb)
xgb_acc = accuracy_score(y_test, y_test_pred_xgb)

models = pd.DataFrame({
    'Models': ['Logistic Regression', 'KNN', 'SVC', 'Decision Tree Classifier', 'Random Forest Classifier', 'Gradient Boosting Classifier', 'XgBoost'],
    'Score': [100*round(lr_acc, 4), 100*round(knn_acc, 4), 100*round(svc_acc, 4), 100*round(dtc_acc, 4), 100*round(rfc_acc, 4), 100*round(gbc_acc, 4), 100*round(xgb_acc, 4)]
})

print(models)
# Out:
#                          Models  Score
# 0           Logistic Regression  64.04
# 1                           KNN  64.04
# 2                           SVC  58.77
# 3      Decision Tree Classifier  57.02
# 4      Random Forest Classifier  59.65
# 5  Gradient Boosting Classifier  57.89
# 6                       XgBoost  62.28

# %% [markdown]
# # Calculation of AUC & ROC and plotting Roc curve

# %%
from sklearn.metrics import roc_curve, auc

#predicted probabilities for each model
y_prob_lr = lr_model.predict_proba(x_test)[:, 1]
y_prob_knn = knn_model.predict_proba(x_test)[:, 1]
y_prob_svc = svc_model.decision_function(x_test) 
y_prob_dtc = dt_model.predict_proba(x_test)[:, 1]
y_prob_rfc = rf_model.predict_proba(x_test)[:, 1]
y_prob_gbc = gb_model.predict_proba(x_test)[:, 1]
y_prob_xgb = xgb_model.predict_proba(x_test)[:, 1]

# Calculate ROC curve and AUC for each model
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_prob_lr)
fpr_knn, tpr_knn, _ = roc_curve(y_test, y_prob_knn)
fpr_svc, tpr_svc, _ = roc_curve(y_test, y_prob_svc)
fpr_dtc, tpr_dtc, _ = roc_curve(y_test, y_prob_dtc)
fpr_rfc, tpr_rfc, _ = roc_curve(y_test, y_prob_rfc)
fpr_gbc, tpr_gbc, _ = roc_curve(y_test, y_prob_gbc)
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_prob_xgb)

# Calculate AUC for each model
roc_auc_lr = auc(fpr_lr, tpr_lr)
roc_auc_knn = auc(fpr_knn, tpr_knn)
roc_auc_svc = auc(fpr_svc, tpr_svc)
roc_auc_dtc = auc(fpr_dtc, tpr_dtc)
roc_auc_rfc = auc(fpr_rfc, tpr_rfc)
roc_auc_gbc = auc(fpr_gbc, tpr_gbc)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

# Plot ROC curves
plt.figure(figsize=(10, 8))
plt.plot(fpr_lr, tpr_lr, label=f'Logistic Regression (AUC = {roc_auc_lr:.2f})')
plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC = {roc_auc_knn:.2f})')
plt.plot(fpr_svc, tpr_svc, label=f'SVC (AUC = {roc_auc_svc:.2f})')
plt.plot(fpr_dtc, tpr_dtc, label=f'Decision Tree (AUC = {roc_auc_dtc:.2f})')
plt.plot(fpr_rfc, tpr_rfc, label=f'Random Forest (AUC = {roc_auc_rfc:.2f})')
plt.plot(fpr_gbc, tpr_gbc, label=f'Gradient Boosting (AUC = {roc_auc_gbc:.2f})')
plt.plot(fpr_xgb, tpr_xgb, label=f'XgBoost (AUC = {roc_auc_xgb:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='grey', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
roc_auc_scores = [roc_auc_lr, roc_auc_knn, roc_auc_svc, roc_auc_dtc, roc_auc_rfc, roc_auc_gbc, roc_auc_xgb]
accuracy_scores = [lr_acc, knn_acc, svc_acc, dtc_acc, rfc_acc, gbc_acc, xgb_acc]

models = ['Logistic Regression', 'KNN', 'SVC', 'Decision Tree', 'Random Forest', 'Gradient Boosting', 'XgBoost']

# Normalize the accuracy scores to make them comparable with ROC AUC
normalized_accuracy = [acc/100 for acc in accuracy_scores]

# Plotting the bar graph
bar_width = 0.35
index = np.arange(len(models))

fig, ax1 = plt.subplots(figsize=(10, 8))

ax1.bar(index, roc_auc_scores, bar_width, label='ROC AUC', color='b', alpha=0.7)
ax1.set_xlabel('Models', fontsize=14)
ax1.set_ylabel('ROC & AUC', fontsize=14)
ax1.set_xticks(index + bar_width/2)
ax1.set_xticklabels(models, rotation=45, ha='right', fontsize=12)
ax1.legend(loc='upper left', fontsize=12)

ax2 = ax1.twinx()
ax2.bar(index + bar_width, normalized_accuracy, bar_width, label='Accuracy', color='r', alpha=0.7)
ax2.set_ylabel('Accuracy', fontsize=14)
ax2.legend(loc='upper right', fontsize=12)

plt.title('Model Comparison: ROC & AUC and Accuracy', fontsize=16)
plt.show()

# %% [markdown]
# # Saving the model

# %%
import pickle
model = lr_acc
# Dump the model to a file named "liver_disease_prediction.pkl"
pickle.dump(model,open("liver_diease_prediction.pkl","wb"))

# %% [markdown]
# # Thanks
